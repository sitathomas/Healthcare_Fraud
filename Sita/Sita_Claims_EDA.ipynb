# %% [markdown]
# ## Setup and Data Import

# %%
import sys
sys.path.insert(0, '..')

from joblib import load

import Sita_Functions as fxns
from Sita_Functions import np, pd

pd.set_option('display.max_columns', None)

import plotly.express as px

import statsmodels.api as sm

# %%
# !python ../Sita_Preprocessing.py

# %%
claims = load('claims.pkl')

# %%
# claims.sample(10)

# %%
# fxns.explore_df(claims)

# %%
numeric_cols = fxns.cols_by_dtype(claims)[0]
categorical_cols = fxns.cols_by_dtype(claims)[1]
date_cols = fxns.cols_by_dtype(claims)[2]

# %% [markdown]
# ## Diagnosis and Procedure Codes

# %% [markdown]
# ### Specific Code to PotentialFraud

# %%
diagnosis_cols = claims.columns[
    claims.columns.str.contains('ClmDiagnosis')].to_list()
procedure_cols = claims.columns[
    claims.columns.str.contains('Procedure')].to_list()

# %%
# px.scatter(claims, 'ClmDiagnosisCode_3', 'PotentialFraud')

# The diagnosis codes with the least missingness (1, 2, and 3) don't seem to have
# a relationship with Potential Fraud

# %%
# px.scatter(claims, 'ClmProcedureCode_3', 'PotentialFraud')

# The procedure codes all have missingness above 95% and don't seem to have
# a relationship with Potential Fraud

# %% [markdown]
# ### Code Quantity by Provider to PotentialFraud

# %%
counts_by_provider = claims.groupby('Provider').count()

# %%
# px.scatter(counts_by_provider[diagnosis_cols].sum(axis=1))

# %%
# px.scatter(counts_by_provider[procedure_cols].sum(axis=1))

# %% [markdown]
# ### Consolidating Diagnosis and Procedure Codes

# %%
# fxns.dummify(claims)
# fxns.consolidate(claims)

# %% [markdown]
# ## Feature Engineering

# %%
counts_by_provider
# Out:
#           BeneID  ClaimID  ClaimStartDt  ClaimEndDt  InscClaimAmtReimbursed  \
# Provider
# PRV51001      25       25            25          25                      25
# PRV51003     132      132           132         132                     132
# PRV51004     149      149           149         149                     149
# PRV51005    1165     1165          1165        1165                    1165
# PRV51007      72       72            72          72                      72
# ...          ...      ...           ...         ...                     ...
# PRV57759      28       28            28          28                      28
# PRV57760      22       22            22          22                      22
# PRV57761      82       82            82          82                      82
# PRV57762       1        1             1           1                       1
# PRV57763     118      118           118         118                     118
#
#           AttendingPhysician  OperatingPhysician  OtherPhysician  AdmissionDt  \
# Provider
# PRV51001                  25                   5              10            5
# PRV51003                 132                  45              25           62
# PRV51004                 149                  27              63            0
# PRV51005                1163                 222             478            0
# PRV51007                  72                  12              26            3
# ...                      ...                 ...             ...          ...
# PRV57759                  28                   1              12            0
# PRV57760                  22                   6               9            0
# PRV57761                  82                  14              36            0
# PRV57762                   1                   0               0            0
# PRV57763                 118                  19              49            0
#
#           ClmAdmitDiagnosisCode  DeductibleAmtPaid  DischargeDt  \
# Provider
# PRV51001                     11                 25            5
# PRV51003                     78                132           62
# PRV51004                     28                149            0
# PRV51005                    252               1165            0
# PRV51007                     17                 72            3
# ...                         ...                ...          ...
# PRV57759                      3                 28            0
# PRV57760                      7                 22            0
# PRV57761                     18                 82            0
# PRV57762                      1                  1            0
# PRV57763                     19                118            0
#
#           DiagnosisGroupCode  ClmDiagnosisCode_1  ClmDiagnosisCode_2  \
# Provider
# PRV51001                   5                  24                  16
# PRV51003                  62                 132                 112
# PRV51004                   0                 143                  91
# PRV51005                   0                1149                 723
# PRV51007                   3                  72                  46
# ...                      ...                 ...                 ...
# PRV57759                   0                  27                  16
# PRV57760                   0                  22                  11
# PRV57761                   0                  82                  55
# PRV57762                   0                   1                   0
# PRV57763                   0                 116                  77
#
#           ClmDiagnosisCode_3  ClmDiagnosisCode_4  ClmDiagnosisCode_5  \
# Provider
# PRV51001                  10                   8                   8
# PRV51003                  92                  78                  66
# PRV51004                  56                  34                  24
# PRV51005                 455                 287                 164
# PRV51007                  29                  21                  14
# ...                      ...                 ...                 ...
# PRV57759                   8                   5                   2
# PRV57760                   8                   5                   3
# PRV57761                  32                  23                  11
# PRV57762                   0                   0                   0
# PRV57763                  46                  23                  17
#
#           ClmDiagnosisCode_6  ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# Provider
# PRV51001                   8                   3                   2
# PRV51003                  58                  55                  50
# PRV51004                  16                   9                   8
# PRV51005                 100                  68                  43
# PRV51007                  12                   9                   6
# ...                      ...                 ...                 ...
# PRV57759                   0                   0                   0
# PRV57760                   2                   1                   0
# PRV57761                   8                   4                   2
# PRV57762                   0                   0                   0
# PRV57763                   9                   4                   3
#
#           ClmDiagnosisCode_9  ClmDiagnosisCode_10  ClmProcedureCode_1  \
# Provider
# PRV51001                   1                    0                   2
# PRV51003                  45                    5                  39
# PRV51004                   4                    0                   0
# PRV51005                  26                    1                   0
# PRV51007                   5                    1                   1
# ...                      ...                  ...                 ...
# PRV57759                   0                    0                   0
# PRV57760                   0                    0                   0
# PRV57761                   2                    0                   0
# PRV57762                   0                    0                   0
# PRV57763                   3                    1                   0
#
#           ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# Provider
# PRV51001                   1                   0                   0
# PRV51003                   9                   0                   0
# PRV51004                   0                   0                   0
# PRV51005                   0                   0                   0
# PRV51007                   0                   0                   0
# ...                      ...                 ...                 ...
# PRV57759                   0                   0                   0
# PRV57760                   0                   0                   0
# PRV57761                   0                   0                   0
# PRV57762                   0                   0                   0
# PRV57763                   0                   0                   0
#
#           ClmProcedureCode_5  ClmProcedureCode_6  IsOutpatient   DOB  DOD  \
# Provider
# PRV51001                   0                   0            25    25    0
# PRV51003                   0                   0           132   132    1
# PRV51004                   0                   0           149   149    1
# PRV51005                   0                   0          1165  1165    4
# PRV51007                   0                   0            72    72    1
# ...                      ...                 ...           ...   ...  ...
# PRV57759                   0                   0            28    28    0
# PRV57760                   0                   0            22    22    0
# PRV57761                   0                   0            82    82    1
# PRV57762                   0                   0             1     1    0
# PRV57763                   0                   0           118   118    0
#
#           Gender  Race  RenalDiseaseIndicator  State  County  \
# Provider
# PRV51001      25    25                     25     25      25
# PRV51003     132   132                    132    132     132
# PRV51004     149   149                    149    149     149
# PRV51005    1165  1165                   1165   1165    1165
# PRV51007      72    72                     72     72      72
# ...          ...   ...                    ...    ...     ...
# PRV57759      28    28                     28     28      28
# PRV57760      22    22                     22     22      22
# PRV57761      82    82                     82     82      82
# PRV57762       1     1                      1      1       1
# PRV57763     118   118                    118    118     118
#
#           NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# Provider
# PRV51001                   25                   25                     25
# PRV51003                  132                  132                    132
# PRV51004                  149                  149                    149
# PRV51005                 1165                 1165                   1165
# PRV51007                   72                   72                     72
# ...                       ...                  ...                    ...
# PRV57759                   28                   28                     28
# PRV57760                   22                   22                     22
# PRV57761                   82                   82                     82
# PRV57762                    1                    1                      1
# PRV57763                  118                  118                    118
#
#           ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# Provider
# PRV51001                        25                         25
# PRV51003                       132                        132
# PRV51004                       149                        149
# PRV51005                      1165                       1165
# PRV51007                        72                         72
# ...                            ...                        ...
# PRV57759                        28                         28
# PRV57760                        22                         22
# PRV57761                        82                         82
# PRV57762                         1                          1
# PRV57763                       118                        118
#
#           ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# Provider
# PRV51001                  25                          25
# PRV51003                 132                         132
# PRV51004                 149                         149
# PRV51005                1165                        1165
# PRV51007                  72                          72
# ...                      ...                         ...
# PRV57759                  28                          28
# PRV57760                  22                          22
# PRV57761                  82                          82
# PRV57762                   1                           1
# PRV57763                 118                         118
#
#           ChronicCond_Depression  ChronicCond_Diabetes  \
# Provider
# PRV51001                      25                    25
# PRV51003                     132                   132
# PRV51004                     149                   149
# PRV51005                    1165                  1165
# PRV51007                      72                    72
# ...                          ...                   ...
# PRV57759                      28                    28
# PRV57760                      22                    22
# PRV57761                      82                    82
# PRV57762                       1                     1
# PRV57763                     118                   118
#
#           ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# Provider
# PRV51001                         25                        25
# PRV51003                        132                       132
# PRV51004                        149                       149
# PRV51005                       1165                      1165
# PRV51007                         72                        72
# ...                             ...                       ...
# PRV57759                         28                        28
# PRV57760                         22                        22
# PRV57761                         82                        82
# PRV57762                          1                         1
# PRV57763                        118                       118
#
#           ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# Provider
# PRV51001                               25                  25
# PRV51003                              132                 132
# PRV51004                              149                 149
# PRV51005                             1165                1165
# PRV51007                               72                  72
# ...                                   ...                 ...
# PRV57759                               28                  28
# PRV57760                               22                  22
# PRV57761                               82                  82
# PRV57762                                1                   1
# PRV57763                              118                 118
#
#           IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# Provider
# PRV51001                        25                     25
# PRV51003                       132                    132
# PRV51004                       149                    149
# PRV51005                      1165                   1165
# PRV51007                        72                     72
# ...                            ...                    ...
# PRV57759                        28                     28
# PRV57760                        22                     22
# PRV57761                        82                     82
# PRV57762                         1                      1
# PRV57763                       118                    118
#
#           OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  PotentialFraud
# Provider
# PRV51001                        25                     25              25
# PRV51003                       132                    132             132
# PRV51004                       149                    149             149
# PRV51005                      1165                   1165            1165
# PRV51007                        72                     72              72
# ...                            ...                    ...             ...
# PRV57759                        28                     28              28
# PRV57760                        22                     22              22
# PRV57761                        82                     82              82
# PRV57762                         1                      1               1
# PRV57763                       118                    118             118
#
# [5410 rows x 55 columns]
