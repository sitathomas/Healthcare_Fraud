# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
descriptions = {
    'MISSING1': 'Average deductible paid for inpatients',
    'MISSING2': 'Average deductible paid for outpatients',
    'MISSING3': 'Whether the provider serves both in/out patients',
    'Alzheimers_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'HeartFailure_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'KidneyDisease_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'Cancer_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'ObstrPulmonary_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'Depression_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'Diabetes_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'IschemicHeart_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'Osteoporosis_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'RheumatoidArthritis_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'Stroke_Chronic_IP_Perc': 'Percentage of inpatients with this chronic disease',
    'Alzheimers_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'HeartFailure_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'KidneyDisease_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'Cancer_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'ObstrPulmonary_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'Depression_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'Diabetes_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'IschemicHeart_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'Osteoporosis_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'RheumatoidArthritis_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'Stroke_Chronic_OP_Perc': 'Percentage of outpatients with this chronic disease',
    'MISSING4': 'Average number of claims per patients',
    'MISSING5': 'Average number of claims per physicians',
    'Att_Phy_Mult': 'Percentage of attending physicians serving for different hospitals (75% threshold)',
    'Oper_Phy_Mult': 'Percentage of operating physicians serving for different hospitals (75% threshold)',
    'Other_Phy_Mult': 'Percentage of other physicians serving for different hospitals (75% threshold)',
    'MISSING6': 'Percentage of inpatients going to different hospitals (75% threshold)',
    'MISSING7': 'Percentage of outpatients going to different hospitals (75% threshold)',
    'DualPatients_Perc': 'Percentage of patients that receive both in/out patient service',
    'HasTop5AdmtCode': 'Percentage of inpatient claims with top 5 admtcode (from PotentialFraud)',
    'IP_UniqueBenes_Count': 'Number of unique inpatient beneficiaries',
    'OP_UniqueBenes_Count': 'Number of unique outpatient beneficiaries',
    'IP_UniqueSt_Count': 'Number of unique states for inpatients',
    'OP_UniqueSt_Count': 'Number of unique states for outpatients',
    'BenesPerAttPhys': 'Patient/Attending Physician Ratio',
    'BenesPerOperPhys': 'Patient/Operating Physician Ratio',
    'BenesPerOthPhys': 'Patient/Other Physician Ratio',
    'Outpatient_Perc': 'Percentage of outpatient claims',
    'HasAllPhysicians_IP_Perc': 'Percentage of inpatient claims that had all physicians involved',
    'HasAllPhysicians_OP_Perc': 'Percentage of outpatient claims that had all physicians involved',
    'HasAnyPhysicians_IP_Perc': 'Percentage of inpatient claims that had any physicians involved',
    'HasAnyPhysicians_OP_Perc': 'Percentage of outpatient claims that had any physicians involved',
    'HasNoPhysicians_IP_Perc': 'Percentage of inpatient claims that had no physicians involved',
    'HasNoPhysicians_OP_Perc': 'Percentage of outpatient claims that had no physicians involved',    
    'HasDied_Perc': 'Percentage of claims where the patient has a date of death',
    'MISSING8': 'Average claim duration for inpatients',
    'MISSING9': 'Average claim duration for outpatients',
    'MISSING10': 'Average amount of reimbursed claims for inpatients',
    'MISSING11': 'Average amount of reimbursed claims for outpatients',
    'MISSING12': 'Average admission duration for inpatients',
    'MISSING13': 'Average age of patients',
    'MISSING14': 'Average number of chronic condition for inpatients',
    'MISSING15': 'Average number of chronic condition for outpatients',
    'MISSING16': 'Average Insurance covered Ratio for inpatients (Reimbursement/(Reimbursement+Deductible)',
    'MISSING17': 'Average Insurance covered Ratio for outpatients',
    'MISSING18': 'Average revenue per day for inpatients',
    'MISSING19': 'Average revenue per day for outpatients',
    'IP_Dup_Perc': 'Percentage of Inpatient duplicate',
    'OP_Dup_Perc': 'Percentage of Outpatient duplicate',
    'MISSING20': 'Average inpatient claim duration of duplicate',
    'MISSING21': 'Average outpatient claim duration of duplicate',
    'OP_No_Diag_Perc': 'Percentage of outpatient with no diagnosis codes',
    'IP_No_Proc_Perc': 'Percentage of inpatient with no procedure codes',
    'In_Top5_St_Perc': 'Percentage of claims from top 5 fraudulent states per provider',
    'GenderZero_Perc': 'Percentage of gender zero per provider'}

descriptions = pd.DataFrame.from_dict(descriptions, orient='index')

# %%
missing = descriptions.index[descriptions.index.str.contains('MISSING')].to_list()
descriptions.loc[missing]
# Out:
#                                                                                                   0
# MISSING1                                                     Average deductible paid for inpatients
# MISSING2                                                    Average deductible paid for outpatients
# MISSING3                                           Whether the provider serves both in/out patients
# MISSING4                                                      Average number of claims per patients
# MISSING5                                                    Average number of claims per physicians
# MISSING6                      Percentage of inpatients going to different hospitals (75% threshold)
# MISSING7                     Percentage of outpatients going to different hospitals (75% threshold)
# MISSING8                                                      Average claim duration for inpatients
# ...
