# %% [markdown]
# # Background research

# %% [markdown]
# Health care fraud has a human face too. Individual victims of health care fraud are sadly easy to find. These are people who are exploited and subjected to unnecessary or unsafe medical procedures. Or whose medical records are compromised or whose legitimate insurance information is used to submit falsified claims.
#
# Some of the more common types of fraud committed by dishonest providers include:
#
# - Billing for services that were never rendered—by using genuine patient information, sometimes obtained through identity theft, to fabricate entire claims or by padding otherwise legitimate claims with charges for procedures or services that did not take place.
# - Billing for more expensive services or procedures than were actually provided or performed, commonly known as "upcoding"—i.e., falsely billing for a higher-priced treatment than was actually provided (which often requires the accompanying "inflation" of the patient's diagnosis code to a more serious condition consistent with the false procedure code).
# - Performing medically unnecessary services solely for the purpose of generating insurance payments—this is seen very often in diagnostic-testing schemes such as nerve-conduction and genetic testing.
# - Misrepresenting non-covered treatments as medically necessary covered treatments for purposes of obtaining insurance payments—this is widely seen in cosmetic-surgery schemes, in which non-covered cosmetic procedures such as "nose jobs" are billed to patients' insurers as deviated-septum repairs.
# - Falsifying a patient's diagnosis and medical record to justify tests, surgeries or other procedures that aren't medically necessary.
# - Unbundling—billing for each step of a procedure as if they are separate procedures.
# - Billing a patient more than the required co-pay amount for services that were prepaid or paid-in-full by the benefit plan under the terms of a managed care contract.
# - Accepting kickbacks for patient referrals.
# - Waiving patient co-pays or deductibles for medical or dental care and over-billing the insurance carrier or benefit plan (insurers often set the policy with regard to the waiver of co-pays through its provider contracting process; while, under Medicare, routinely waiving co-pays is prohibited and may only be waived due to "financial hardship").
#
# ### Problem Statement
#
# The goal of this project is to " predict the potentially fraudulent providers " based on the claims filed by them.along with this, we will also discover important variables helpful in detecting the behaviour of potentially fraud providers. further, we will study fraudulent patterns in the provider's claims to understand the future behaviour of providers.

# %% [markdown]
# # Dataset

# %%
import pandas as pd

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
# import csv
inpatient = pd.read_csv("../data/Train_Inpatientdata-1542865627584.csv")
outpatient = pd.read_csv("../data/Train_Outpatientdata-1542865627584.csv")
beneficiary = pd.read_csv("../data/Train_Beneficiarydata-1542865627584.csv")
target = pd.read_csv("../data/Train-1542865627584.csv")

# %%
# how do they look?
display(inpatient.head(3))
display(outpatient.head(3))
display(beneficiary.head(3))
display(target.head(3))
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6
# 0                 NaN
# 1                 NaN
# 2                 NaN
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# 1            NaN               6115                NaN                NaN
# 2            NaN               2723                NaN                NaN
#
#   ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6 ClmDiagnosisCode_7  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
#
#   ClmDiagnosisCode_8 ClmDiagnosisCode_9 ClmDiagnosisCode_10  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
#
#    ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
#
#    DeductibleAmtPaid ClmAdmitDiagnosisCode
# 0                  0                 56409
# 1                  0                 79380
# 2                  0                   NaN
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          2                   2
# 2                         2                          2                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       2                     2
# 2                           2                       2                     2
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          2                         2
# 2                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                2                   2
# 2                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                         0                      0                        30
# 2                         0                      0                        90
#
#    OPAnnualDeductibleAmt
# 0                     70
# 1                     50
# 2                     40
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No

# %%
# join all tables into one
train = inpatient.append(outpatient, ignore_index=True, sort=False).merge(beneficiary).merge(target)
display(train[train['BeneID'] == 'BENE11011'])

train.shape
# Out:
#         BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 370  BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 459  BENE11011  CLM144521   2009-01-18  2009-01-18  PRV52314
# 682  BENE11011  CLM347780   2009-05-08  2009-05-08  PRV51012
# 730  BENE11011  CLM507201   2009-08-04  2009-08-04  PRV51063
#
#      InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 370                    5000          PHY369659          PHY392961
# 459                      50          PHY379398                NaN
# 682                      50          PHY429635                NaN
# 730                      80          PHY345842                NaN
#
#     OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 370      PHY349768  2009-02-14                   431             1068.0
# 459            NaN         NaN                 78900                0.0
# 682      PHY322331         NaN                 37611                0.0
# 730            NaN         NaN                   311                0.0
#
#     DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 370  2009-02-22                067              43491               2762
# 459         NaN                NaN              78969              78701
# 682         NaN                NaN              37500                NaN
# 730         NaN                NaN              29633               2724
#
#     ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 370               7843              32723              V1041
# 459              V5866              59389               2449
# 682                NaN                NaN                NaN
# 730               3009                NaN                NaN
#
#     ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 370               4254              25062              40390
# 459                NaN                NaN                NaN
# 682                NaN                NaN                NaN
# 730                NaN                NaN                NaN
#
#     ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 370               4019                 NaN               331.0
# 459                NaN                 NaN                 NaN
# 682                NaN                 NaN                 NaN
# 730                NaN                 NaN                 NaN
#
#      ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 370                 NaN                 NaN                 NaN
# 459                 NaN                 NaN                 NaN
# 682                 NaN                 NaN                 NaN
# 730                 NaN                 NaN                 NaN
#
#      ClmProcedureCode_5  ClmProcedureCode_6  isOutpatient         DOB  DOD  \
# 370                 NaN                 NaN             0  1914-03-01  NaN
# 459                 NaN                 NaN             1  1914-03-01  NaN
# 682                 NaN                 NaN             1  1914-03-01  NaN
# 730                 NaN                 NaN             1  1914-03-01  NaN
#
#      Gender  Race RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 370       2     2                     0      1     360                   12
# 459       2     2                     0      1     360                   12
# 682       2     2                     0      1     360                   12
# 730       2     2                     0      1     360                   12
#
#      NoOfMonths_PartBCov  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 370                   12                      2                         1
# 459                   12                      2                         1
# 682                   12                      2                         1
# 730                   12                      2                         1
#
#      ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 370                          1                   2
# 459                          1                   2
# 682                          1                   2
# 730                          1                   2
#
#      ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 370                           2                       1                     1
# 459                           2                       1                     1
# 682                           2                       1                     1
# 730                           2                       1                     1
#
#      ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 370                          2                         2
# 459                          2                         2
# 682                          2                         2
# 730                          2                         2
#
#      ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 370                                1                   1
# 459                                1                   1
# 682                                1                   1
# 730                                1                   1
#
#      IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 370                      5000                   1068
# 459                      5000                   1068
# 682                      5000                   1068
# 730                      5000                   1068
#
#      OPAnnualReimbursementAmt  OPAnnualDeductibleAmt PotentialFraud
# 370                       250                    320             No
# 459                       250                    320             No
# 682                       250                    320             No
# 730                       250                    320             No
# (558211, 56)

# %%
train.to_csv(r'../data/train.csv', index = False)

# %%
# checking stuff
inpatient.AdmissionDt.unique()
# Out:
# array(['2009-04-12', '2009-08-31', '2009-09-17', '2009-02-14',
#        '2009-08-13', '2009-10-06', '2009-01-02', '2009-08-03',
#        '2009-08-06', '2008-12-29', '2009-07-01', '2009-09-30',
#        '2009-08-26', '2009-06-10', '2009-12-07', '2009-06-26',
#        '2009-01-19', '2009-06-07', '2009-06-25', '2009-07-28',
#        '2009-02-03', '2009-02-12', '2009-03-06', '2009-07-19',
#        '2009-11-09', '2009-02-09', '2009-08-04', '2009-12-29',
#        '2009-04-28', '2009-07-18', '2009-06-19', '2009-08-09',
#        '2009-03-15', '2009-01-28', '2009-01-03', '2009-01-12',
#        '2009-07-07', '2009-04-14', '2009-10-19', '2009-03-30',
#        '2009-11-23', '2009-01-14', '2009-12-04', '2009-01-21',
#        '2009-03-25', '2009-10-05', '2009-10-01', '2009-10-31',
#        '2009-12-05', '2009-02-01', '2009-03-01', '2009-12-20',
#        '2009-10-25', '2009-08-12', '2009-01-22', '2009-02-15',
#        '2009-04-06', '2009-09-06', '2009-06-13', '2009-09-23',
#        '2009-11-22', '2009-03-17', '2008-12-30', '2009-01-26',
#        '2009-08-18', '2009-08-15', '2009-09-04', '2009-11-10',
#        '2009-03-24', '2009-10-28', '2009-06-29', '2009-08-20',
#        '2009-01-24', '2009-04-07', '2009-01-18', '2009-01-15',
#        '2009-09-29', '2009-11-12', '2009-05-04', '2008-12-31',
#        '2009-07-13', '2009-11-20', '2009-11-18', '2009-12-13',
#        '2009-07-09', '2009-01-09', '2009-01-25', '2009-08-14',
#        '2009-08-07', '2009-02-21', '2009-07-14', '2009-05-10',
#        '2009-05-14', '2009-03-22', '2009-11-03', '2009-04-16',
#        '2009-09-18', '2009-01-07', '2009-04-19', '2009-05-05',
#        '2009-11-16', '2009-02-26', '2009-02-18', '2009-03-05',
#        '2009-12-23', '2009-02-13', '2009-07-23', '2009-09-05',
#        '2009-09-09', '2009-02-23', '2009-02-07', '2009-01-10',
#        '2009-03-10', '2009-08-27', '2009-08-16', '2009-10-21',
#        '2009-10-22', '2009-01-30', '2009-04-22', '2009-08-23',
#        '2009-12-10', '2009-05-15', '2009-11-07', '2009-07-20',
#        '2009-02-22', '2009-03-04', '2009-10-02', '2009-02-04',
#        '2009-11-19', '2009-11-30', '2009-09-15', '2009-03-03',
#        '2009-01-27', '2009-02-05', '2009-05-29', '2009-06-21',
#        '2009-07-04', '2009-07-05', '2009-05-08', '2009-07-22',
#        '2009-11-29', '2009-09-25', '2009-11-24', '2009-10-10',
#        '2009-11-13', '2009-05-30', '2009-04-29', '2009-01-20',
#        '2009-03-14', '2008-12-28', '2009-10-03', '2009-06-15',
#        '2009-08-25', '2009-10-26', '2009-01-01', '2009-08-30',
#        '2009-06-27', '2009-09-10', '2009-02-19', '2009-11-04',
#        '2009-10-04', '2009-06-17', '2009-12-01', '2009-02-02',
#        '2009-04-23', '2009-06-20', '2009-08-08', '2009-03-07',
#        '2008-12-24', '2009-10-07', '2009-09-20', '2009-04-11',
#        '2009-09-07', '2009-06-14', '2009-02-27', '2009-03-21',
#        '2009-02-20', '2009-02-25', '2009-07-21', '2009-06-18',
#        '2009-08-17', '2009-09-16', '2009-04-04', '2009-06-23',
#        '2009-07-24', '2009-08-02', '2009-06-12', '2009-08-28',
#        '2009-03-12', '2009-04-03', '2009-09-12', '2009-01-13',
#        '2009-12-02', '2009-07-10', '2009-02-16', '2009-04-15',
#        '2009-07-31', '2009-12-24', '2009-06-06', '2009-04-17',
#        '2009-07-03', '2009-07-08', '2009-08-05', '2009-03-13',
#        '2009-06-28', '2009-01-16', '2009-05-12', '2009-04-21',
#        '2009-02-10', '2009-12-21', '2009-10-09', '2009-08-19',
#        '2009-06-01', '2009-05-24', '2009-12-17', '2009-10-29',
#        '2009-11-15', '2009-05-16', '2009-11-11', '2009-04-13',
#        '2009-03-20', '2009-12-16', '2009-05-02', '2009-05-28',
#        '2009-11-14', '2009-07-27', '2009-12-14', '2009-08-24',
#        '2009-03-19', '2009-05-31', '2009-04-08', '2009-09-26',
#        '2009-01-31', '2009-12-25', '2009-08-01', '2009-08-21',
#        '2009-08-22', '2009-10-13', '2009-09-22', '2009-09-24',
#        '2009-03-09', '2009-09-28', '2009-05-25', '2009-09-19',
#        '2009-05-03', '2008-12-27', '2009-08-11', '2009-01-23',
#        '2009-04-09', '2009-05-06', '2009-06-08', '2009-12-19',
#        '2009-03-26', '2009-12-09', '2009-07-02', '2009-07-06',
#        '2009-10-14', '2009-07-12', '2009-11-28', '2009-03-18',
#        '2009-05-17', '2009-09-27', '2009-03-31', '2009-04-20',
#        '2009-04-18', '2009-03-11', '2009-06-04', '2009-02-11',
#        '2009-04-24', '2008-12-02', '2009-06-11', '2009-10-24',
#        '2009-03-27', '2009-04-05', '2009-03-29', '2008-12-17',
#        '2009-01-06', '2009-01-11', '2009-03-23', '2009-04-01',
#        '2009-12-06', '2009-06-09', '2009-07-17', '2009-03-08',
#        '2009-04-30', '2009-10-12', '2009-07-25', '2009-01-08',
#        '2009-05-19', '2009-11-08', '2009-10-27', '2009-02-24',
#        '2009-12-27', '2009-05-27', '2009-10-30', '2009-04-02',
#        '2009-06-30', '2009-08-10', '2009-11-02', '2009-06-16',
#        '2009-12-11', '2009-07-29', '2009-06-22', '2009-01-29',
#        '2009-09-01', '2009-04-26', '2009-05-21', '2009-04-10',
#        '2009-05-07', '2009-06-02', '2009-05-13', '2009-02-17',
#        '2009-01-05', '2009-07-11', '2009-09-14', '2009-11-01',
#        '2008-12-25', '2009-08-29', '2009-10-18', '2009-01-04',
#        '2009-06-05', '2009-01-17', '2009-09-02', '2009-12-08',
#        '2009-05-09', '2008-12-13', '2009-05-18', '2009-11-17',
#        '2009-12-22', '2009-10-17', '2009-11-06', '2009-05-22',
#        '2009-10-11', '2009-07-26', '2009-10-16', '2009-05-11',
#        '2009-09-21', '2009-10-15', '2009-02-08', '2009-03-28',
#        '2009-11-21', '2009-12-15', '2009-09-11', '2009-02-28',
#        '2008-12-18', '2009-04-27', '2009-03-16', '2008-12-20',
#        '2009-11-05', '2009-06-24', '2009-05-20', '2009-10-23',
#        '2009-09-03', '2009-06-03', '2009-07-30', '2009-02-06',
#        '2008-12-26', '2009-05-23', '2009-03-02', '2009-11-27',
#        '2009-04-25', '2009-11-26', '2008-12-09', '2009-11-25',
#        '2009-12-03', '2009-10-08', '2009-05-01', '2009-09-08',
#        '2008-12-22', '2009-09-13', '2009-12-26', '2009-07-16',
#        '2009-12-18', '2009-05-26', '2009-12-28', '2009-10-20',
#        '2009-07-15', '2008-12-12', '2008-12-23', '2009-12-12',
#        '2008-12-19', '2009-12-30', '2008-12-21', '2008-11-29',
#        '2008-12-14', '2008-12-07', '2008-12-03', '2008-12-05',
#        '2008-12-15', '2008-12-11', '2008-12-08', '2008-12-01',
#        '2008-11-28', '2008-12-06', '2008-12-16', '2008-11-27',
#        '2009-12-31', '2008-12-10'], dtype=object)

# %%
a = outpatient[outpatient['BeneID'] == 'BENE46822']
a
# Out:
#            BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 125083  BENE46822  CLM294427   2009-04-09  2009-04-09  PRV55912
# 125084  BENE46822  CLM460990   2009-07-09  2009-07-09  PRV54742
# 125085  BENE46822  CLM692852   2009-11-21  2009-11-21  PRV54786
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 125083                    2000          PHY420794          PHY420794
# 125084                    2100          PHY363761                NaN
# 125085                     200          PHY395758                NaN
#
#        OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 125083            NaN              40210              28521
# 125084      PHY335146               7284              71946
# 125085      PHY395758              44324                NaN
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 125083               5856               2749               2724
# 125084                NaN                NaN                NaN
# 125085                NaN                NaN                NaN
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 125083              V5866                NaN                NaN
# 125084                NaN                NaN                NaN
# 125085                NaN                NaN                NaN
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 125083                NaN                 NaN                 NaN
# 125084                NaN                 NaN                 NaN
# 125085                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 125083                 NaN                 NaN                 NaN
# 125084                 NaN                 NaN                 NaN
# 125085                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  DeductibleAmtPaid  \
# 125083                 NaN                 NaN                  0
# 125084                 NaN                 NaN                  0
# 125085                 NaN                 NaN                  0
#
#        ClmAdmitDiagnosisCode
# 125083                   NaN
# 125084                   NaN
# 125085                   NaN

# %%
pd.to_datetime(a['AdmissionDt'], format='%Y-%m-%d')
a
# Out:
#          BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 9719  BENE46822  CLM41425   2009-03-06  2009-03-08  PRV55978
#
#       InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 9719                    8000          PHY396846                NaN
#
#      OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 9719            NaN  2009-03-06                 49121             1068.0
#
#      DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 9719  2009-03-08                178              49322               5849
#
#      ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 9719              V1005                311               4019
#
#      ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 9719              42731              28860               4400
#
#      ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 9719              25000                 NaN                 NaN
#
#       ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 9719                 NaN                 NaN                 NaN
#
#       ClmProcedureCode_5  ClmProcedureCode_6
# 9719                 NaN                 NaN
