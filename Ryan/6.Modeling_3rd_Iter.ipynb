# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Load Data</a></span></li></ul></li><li><span><a href="#Train-test-split" data-toc-modified-id="Train-test-split-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Train test split</a></span></li><li><span><a href="#Classification-modeling" data-toc-modified-id="Classification-modeling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Classification modeling</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Ridge-Classifer" data-toc-modified-id="Ridge-Classifer-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Ridge Classifer</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Gradient Boosting</a></span></li><li><span><a href="#SVM" data-toc-modified-id="SVM-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>SVM</a></span></li><li><span><a href="#GNB" data-toc-modified-id="GNB-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>GNB</a></span></li></ul></li><li><span><a href="#ROC-AUC-Curve" data-toc-modified-id="ROC-AUC-Curve-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ROC AUC Curve</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import warnings
# %matplotlib inline
sns.set(style = "whitegrid")
sns.set_palette("icefire")
plt.rcParams['figure.figsize'] = (9, 6)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings(action="ignore")

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, recall_score, roc_curve, roc_auc_score
from collections import Counter
from sklearn.utils.class_weight import compute_sample_weight

# %% [markdown]
# ## Load Data

# %%
providers = joblib.load('providers_Third.pkl')
print(providers.shape)
providers.head()
# Out:
# (5410, 92)
#           PotentialFraud  Perc_Outpatient  DualPatientProvider  \
# Provider
# PRV51001               0         0.800000                  1.0
# PRV51003               1         0.530303                  1.0
# PRV51004               0         1.000000                  0.0
# PRV51005               1         1.000000                  0.0
# PRV51007               0         0.958333                  1.0
#
#           Perc_DualPatientType  Ratio_ClaimsPerPatient  \
# Provider
# PRV51001              0.400000                1.041667
# PRV51003              0.500000                1.128205
# PRV51004              0.208054                1.079710
# PRV51005              0.248069                2.353535
# PRV51007              0.277778                1.241379
#
#           Ratio_ClaimsPerAttPhys  Perc_ClaimsPerTopFraudState  \
# Provider
# PRV51001                1.785714                          0.0
# PRV51003                3.000000                          0.0
# PRV51004                3.921053                          0.0
# PRV51005              194.166667                          0.0
# PRV51007                7.200000                          0.0
#
#           Perc_HasTop5AdmtCode  Perc_MultHospAttPhys  Perc_MultHospOperPhys  \
# Provider
# PRV51001              0.040000              0.240000               0.040000
# PRV51003              0.060606              0.007576               0.000000
# PRV51004              0.013423              0.167785               0.013423
# PRV51005              0.032618              0.000000               0.000000
# PRV51007              0.027778              0.597222               0.083333
#
#           Perc_MultHospOtherPhys  IP_Perc_Duplicates  IP_Count_UniquePatients  \
# Provider
# PRV51001                0.000000            0.000000                      5.0
# PRV51003                0.000000            0.016129                     53.0
# PRV51004                0.000000            0.000000                      0.0
# PRV51005                0.000000            0.000000                      0.0
# PRV51007                0.027778            0.000000                      3.0
#
#           IP_Count_UniqueState  IP_Mean_AgeAtClaim  IP_Perc_HasDied  \
# Provider
# PRV51001                   1.0           77.600000         0.000000
# PRV51003                   3.0           69.935484         0.016129
# PRV51004                   0.0            0.000000         0.000000
# PRV51005                   0.0            0.000000         0.000000
# PRV51007                   1.0           78.000000         0.000000
#
#           IP_Perc_GenderZero  IP_Perc_RaceOne  IP_Perc_RaceTwo  \
# Provider
# PRV51001            0.400000         1.000000         0.000000
# PRV51003            0.338710         0.790323         0.209677
# PRV51004            0.000000         0.000000         0.000000
# PRV51005            0.000000         0.000000         0.000000
# PRV51007            0.333333         0.000000         0.000000
#
#           IP_Perc_RaceThree  IP_Mean_NumChronicConds  \
# Provider
# PRV51001                0.0                 6.000000
# PRV51003                0.0                 4.919355
# PRV51004                0.0                 0.000000
# PRV51005                0.0                 0.000000
# PRV51007                0.0                 5.666667
#
#           IP_Perc_Alzheimers_Chronic  IP_Perc_Cancer_Chronic  \
# Provider
# PRV51001                    0.400000                0.200000
# PRV51003                    0.516129                0.112903
# PRV51004                    0.000000                0.000000
# PRV51005                    0.000000                0.000000
# PRV51007                    0.666667                0.000000
#
#           IP_Perc_Depression_Chronic  IP_Perc_Diabetes_Chronic  \
# Provider
# PRV51001                    0.800000                  0.800000
# PRV51003                    0.403226                  0.790323
# PRV51004                    0.000000                  0.000000
# PRV51005                    0.000000                  0.000000
# PRV51007                    0.666667                  1.000000
#
#           IP_Perc_HeartFailure_Chronic  IP_Perc_IschemicHeart_Chronic  \
# Provider
# PRV51001                      0.800000                       0.800000
# PRV51003                      0.580645                       0.887097
# PRV51004                      0.000000                       0.000000
# PRV51005                      0.000000                       0.000000
# PRV51007                      1.000000                       1.000000
#
#           IP_Perc_KidneyDisease_Chronic  IP_Perc_ObstrPulmonary_Chronic  \
# Provider
# PRV51001                       0.800000                        0.400000
# PRV51003                       0.629032                        0.370968
# PRV51004                       0.000000                        0.000000
# PRV51005                       0.000000                        0.000000
# PRV51007                       0.333333                        0.000000
#
#           IP_Perc_Osteoporosis_Chronic  IP_Perc_RheumatoidArthritis_Chronic  \
# Provider
# PRV51001                      0.000000                             0.600000
# PRV51003                      0.209677                             0.306452
# PRV51004                      0.000000                             0.000000
# PRV51005                      0.000000                             0.000000
# PRV51007                      0.000000                             0.333333
#
#           IP_Perc_Stroke_Chronic  IP_Perc_HasRenalDisease  \
# Provider
# PRV51001                0.400000                 0.400000
# PRV51003                0.112903                 0.274194
# PRV51004                0.000000                 0.000000
# PRV51005                0.000000                 0.000000
# PRV51007                0.666667                 0.333333
#
#           IP_Mean_ClaimDuration  IP_Mean_AdmitDuration  \
# Provider
# PRV51001               6.000000               6.000000
# PRV51003               6.161290               6.161290
# PRV51004               0.000000               0.000000
# PRV51005               0.000000               0.000000
# PRV51007               6.333333               6.333333
#
#           IP_Mean_NoOfMonths_PartACov  IP_Mean_NoOfMonths_PartBCov  \
# Provider
# PRV51001                    12.000000                    12.000000
# PRV51003                    11.806452                    11.806452
# PRV51004                     0.000000                     0.000000
# PRV51005                     0.000000                     0.000000
# PRV51007                    12.000000                    12.000000
#
#           IP_Mean_ClaimCost  IP_Mean_DailyClaimCost  \
# Provider
# PRV51001       20468.000000             4077.360000
# PRV51003       10309.935484             2384.941628
# PRV51004           0.000000                0.000000
# PRV51005           0.000000                0.000000
# PRV51007        7401.333333             1255.588889
#
#           IP_Mean_DeductibleAmtPaid  IP_Mean_InscClaimAmtReimbursed  \
# Provider
# PRV51001                     1068.0                    19400.000000
# PRV51003                     1068.0                     9241.935484
# PRV51004                        0.0                        0.000000
# PRV51005                        0.0                        0.000000
# PRV51007                     1068.0                     6333.333333
#
#           IP_Mean_InsReimbursementRatio  IP_Mean_AnnualDeductibleAmt  \
# Provider
# PRV51001                       0.878279                   897.120000
# PRV51003                       0.821059                   931.424242
# PRV51004                       0.000000                   434.953020
# PRV51005                       0.000000                   379.162232
# PRV51007                       0.829955                   445.000000
#
#           IP_Mean_AnnualReimbursementAmt  IP_Perc_No_ProcCode  \
# Provider
# PRV51001                    17606.000000             0.600000
# PRV51003                     7568.181818             0.370968
# PRV51004                     4351.879195             0.000000
# PRV51005                     3623.991416             0.000000
# PRV51007                     3050.000000             0.666667
#
#           IP_Perc_HasAllPhys  IP_Perc_HasNoPhys  IP_Perc_MultHosp  \
# Provider
# PRV51001                 0.2                0.0          0.160000
# PRV51003                 0.0                0.0          0.045455
# PRV51004                 0.0                0.0          0.060403
# PRV51005                 0.0                0.0          0.048069
# PRV51007                 0.0                0.0          0.069444
#
#           OP_Perc_Duplicates  OP_Count_UniquePatients  OP_Count_UniqueState  \
# Provider
# PRV51001            0.550000                     19.0                   1.0
# PRV51003            0.357143                     66.0                   3.0
# PRV51004            0.461538                    138.0                   9.0
# PRV51005            0.452257                    495.0                   4.0
# PRV51007            0.420290                     56.0                   2.0
#
#           OP_Mean_AgeAtClaim  OP_Perc_HasDied  OP_Perc_GenderZero  \
# Provider
# PRV51001           77.950000         0.000000            0.350000
# PRV51003           68.371429         0.000000            0.471429
# PRV51004           71.302013         0.006711            0.308725
# PRV51005           69.567382         0.003433            0.438627
# PRV51007           67.956522         0.014493            0.478261
#
#           OP_Perc_RaceOne  OP_Perc_RaceTwo  OP_Perc_RaceThree  \
# Provider
# PRV51001         0.800000         0.200000           0.000000
# PRV51003         0.828571         0.157143           0.000000
# PRV51004         0.000000         0.000000           0.000000
# PRV51005         0.805369         0.161074           0.033557
# PRV51007         0.766524         0.224893           0.008584
#
#           OP_Mean_NumChronicConds  OP_Perc_Alzheimers_Chronic  \
# Provider
# PRV51001                 5.450000                    0.650000
# PRV51003                 4.214286                    0.342857
# PRV51004                 4.342282                    0.429530
# PRV51005                 4.335622                    0.365665
# PRV51007                 4.101449                    0.347826
#
#           OP_Perc_Cancer_Chronic  OP_Perc_Depression_Chronic  \
# Provider
# PRV51001                0.200000                    0.250000
# PRV51003                0.042857                    0.414286
# PRV51004                0.107383                    0.422819
# PRV51005                0.141631                    0.416309
# PRV51007                0.173913                    0.391304
#
#           OP_Perc_Diabetes_Chronic  OP_Perc_HeartFailure_Chronic  \
# Provider
# PRV51001                  0.850000                      0.750000
# PRV51003                  0.728571                      0.628571
# PRV51004                  0.704698                      0.590604
# PRV51005                  0.685837                      0.583691
# PRV51007                  0.666667                      0.536232
#
#           OP_Perc_IschemicHeart_Chronic  OP_Perc_KidneyDisease_Chronic  \
# Provider
# PRV51001                       0.950000                       0.650000
# PRV51003                       0.814286                       0.357143
# PRV51004                       0.724832                       0.335570
# PRV51005                       0.768240                       0.435193
# PRV51007                       0.695652                       0.304348
#
#           OP_Perc_ObstrPulmonary_Chronic  OP_Perc_Osteoporosis_Chronic  \
# Provider
# PRV51001                        0.400000                      0.300000
# PRV51003                        0.257143                      0.285714
# PRV51004                        0.275168                      0.328859
# PRV51005                        0.253219                      0.295279
# PRV51007                        0.231884                      0.304348
#
#           OP_Perc_RheumatoidArthritis_Chronic  OP_Perc_Stroke_Chronic  \
# Provider
# PRV51001                             0.250000                0.200000
# PRV51003                             0.271429                0.071429
# PRV51004                             0.308725                0.114094
# PRV51005                             0.284120                0.106438
# PRV51007                             0.304348                0.144928
#
#           OP_Perc_HasRenalDisease  OP_Mean_ClaimDuration  \
# Provider
# PRV51001                 0.300000               1.550000
# PRV51003                 0.171429               3.357143
# PRV51004                 0.154362               2.429530
# PRV51005                 0.222318               2.088412
# PRV51007                 0.144928               1.768116
#
#           OP_Mean_NoOfMonths_PartACov  OP_Mean_NoOfMonths_PartBCov  \
# Provider
# PRV51001                    12.000000                    12.000000
# PRV51003                    11.828571                    11.928571
# PRV51004                    11.865772                    11.959732
# PRV51005                    11.907296                    11.939914
# PRV51007                    11.826087                    11.826087
#
#           OP_Mean_ClaimCost  OP_Mean_DailyClaimCost  \
# Provider
# PRV51001         382.000000              307.000000
# PRV51003         467.714286              336.440760
# PRV51004         352.214765              250.363050
# PRV51005         244.300429              196.533055
# PRV51007         214.057971              199.685990
#
#           OP_Mean_DeductibleAmtPaid  OP_Mean_InscClaimAmtReimbursed  \
# Provider
# PRV51001                   0.000000                      382.000000
# PRV51003                   1.000000                      466.714286
# PRV51004                   2.080537                      350.134228
# PRV51005                   3.175966                      241.124464
# PRV51007                   0.869565                      213.188406
#
#           OP_Mean_InsReimbursementRatio  OP_Mean_AnnualDeductibleAmt  \
# Provider
# PRV51001                       1.000000                   463.920000
# PRV51003                       0.994032                   737.121212
# PRV51004                       0.978485                   622.751678
# PRV51005                       0.980747                   636.328755
# PRV51007                       0.992157                   469.722222
#
#           OP_Mean_AnnualReimbursementAmt  OP_Perc_No_DiagCode  \
# Provider
# PRV51001                     2615.200000             0.000000
# PRV51003                     2678.181818             0.000000
# PRV51004                     2194.899329             0.040268
# PRV51005                     2109.733906             0.011159
# PRV51007                     1729.722222             0.000000
#
#           OP_Perc_HasAllPhys  OP_Perc_HasNoPhys  OP_Perc_MultHosp  \
# Provider
# PRV51001            0.050000           0.000000          0.920000
# PRV51003            0.057143           0.000000          0.818182
# PRV51004            0.080537           0.000000          0.899329
# PRV51005            0.084120           0.001717          0.731330
# PRV51007            0.115942           0.000000          0.902778
#
#           IP_Mean_PatientsPerAttPhys  IP_Mean_PatientsPerOperPhys  \
# Provider
# PRV51001                        1.25                          1.0
# PRV51003                       29.50                         20.0
# PRV51004                        0.00                          0.0
# PRV51005                        0.00                          0.0
# PRV51007                        1.50                          1.0
#
#           IP_Mean_PatientsPerOtherPhys  IP_AgeRange  \
# Provider
# PRV51001                           1.0         26.0
# PRV51003                           0.0         55.0
# PRV51004                           0.0          0.0
# PRV51005                           0.0          0.0
# PRV51007                           0.0         10.0
#
#           OP_Mean_PatientsPerAttPhys  OP_Mean_PatientsPerOperPhys  \
# Provider
# PRV51001                    2.000000                     1.000000
# PRV51003                    1.590909                     1.000000
# PRV51004                    3.921053                     1.421053
# PRV51005                  147.833333                    33.833333
# PRV51007                    8.000000                     2.750000
#
#           OP_Mean_PatientsPerOtherPhys  OP_AgeRange
# Provider
# PRV51001                      1.285714         40.0
# PRV51003                      1.136364         59.0
# PRV51004                      2.423077         74.0
# PRV51005                    102.750000         72.0
# PRV51007                      3.571429         73.0

# %% [markdown]
# # Train test split

# %%
# Separate input features (X) and target variable (y)
y = providers['PotentialFraud']
X = providers.drop('PotentialFraud', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    stratify = y, 
                                                    test_size = 0.3, 
                                                    random_state = 0)

# %% [markdown]
# # Classification modeling

# %%
# Stratified Cross Validation needs to be applied
skf = StratifiedKFold(n_splits = 5, random_state = 0, shuffle = True)

# %%
# Apply Scaling
scaler = MinMaxScaler()
X_train_stan = pd.DataFrame(scaler.fit_transform(X_train), columns=X.columns)
X_test_stan = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
# Model evaluation metric: Recall score
def eval_model(model, best_model, X_train, X_test, y_train, y_test):
    print(model,'score')
    print('-'*30)
    print('Train: recall score:', round(recall_score(y_train, best_model.predict(X_train)),5))
    print('Test: recall score:', round(recall_score(y_test, best_model.predict(X_test)),5))
    print(' ')
    print("Train Test Confusion Matrix")
    print('-'*30)
    print('Train Set')
    print(confusion_matrix(y_train, best_model.predict(X_train)))
    print('Test Set')
    print(confusion_matrix(y_test, best_model.predict(X_test)))

# %% [markdown]
# ## Logistic Regression

# %%
logistic = LogisticRegression(random_state = 0, solver="liblinear", penalty = 'l1', class_weight = 'balanced')

# %%
param_grid = {'C': np.logspace(-2,1,30),
              'tol': np.logspace(-3,1,30),
              'max_iter': [120,150,200]
              }
logisticcv = RandomizedSearchCV(logistic, param_grid, scoring = 'recall', cv = skf)
para_search = logisticcv.fit(X_train_stan, y_train)
best_logistic = para_search.best_estimator_
print('Best estimator:', best_logistic)
# Out:
# Best estimator: LogisticRegression(C=0.4520353656360243, class_weight='balanced', max_iter=200,
#                    penalty='l1', random_state=0, solver='liblinear',
#                    tol=0.002592943797404667)

# %%
eval_model('Logistic Regression', best_logistic, X_train_stan, X_test_stan, y_train, y_test)
# Out:
# Logistic Regression score
# ------------------------------
# Train: recall score: 0.90678
# Test: recall score: 0.89474
#
# Train Test Confusion Matrix
# ------------------------------
# Train Set
# [[2902  531]
#  [  33  321]]
# Test Set
# [[1253  218]
#  [  16  136]]

# %%
logistic_coef = pd.DataFrame(best_logistic.coef_.T, index = X_train.columns).rename(columns = {0:"Coef."})
logistic_coef = logistic_coef.reindex(logistic_coef["Coef."].abs().sort_values(ascending = False).index)
logistic_coef = logistic_coef.reset_index()
plt.figure(figsize = (5,5))
sns.barplot(data = logistic_coef[logistic_coef['Coef.'] != 0], x = 'Coef.', y = 'index');
plt.title('Coefficients of Penalized Logistic Regression Model');
plt.ylabel('');

# %%
# joblib.dump(best_logistic,'best_logistic.pkl')

# %% [markdown]
# ## Ridge Classifer

# %%
logistic_coef = logistic_coef.reset_index()
notimportant = logistic_coef[logistic_coef['Coef.'].abs() == 0]['index'].tolist()

# %%
# Reset the dataset with selective columns
X_train_reduced = X_train_stan.iloc[:,~X_train_stan.columns.isin(notimportant)]
X_test_reduced = X_test_stan.iloc[:,~X_test_stan.columns.isin(notimportant)]

# %%
ridge = RidgeClassifier(random_state = 0, class_weight = 'balanced')

# %%
param_grid = {'alpha': np.logspace(-5,-2,50)}
ridgecv = GridSearchCV(ridge, param_grid = param_grid, scoring = 'recall', cv = skf)
para_search = ridgecv.fit(X_train_reduced, y_train)
best_ridge = para_search.best_estimator_
print('Best estimator:', best_ridge)
# Out:
# Best estimator: RidgeClassifier(alpha=0.0018420699693267163, class_weight='balanced',
#                 random_state=0)

# %%
eval_model('Ridge Classifier', best_ridge, X_train_reduced, X_test_reduced, y_train, y_test)
# Out:
# Ridge Classifier score
# ------------------------------
# Train: recall score: 0.90395
# Test: recall score: 0.90132
#
# Train Test Confusion Matrix
# ------------------------------
# Train Set
# [[2824  609]
#  [  34  320]]
# Test Set
# [[1232  239]
#  [  15  137]]

# %%
ridge_coef = pd.DataFrame(best_ridge.coef_.T, index = X_train_reduced.columns).rename(columns = {0:"Coef."})
ridge_coef = ridge_coef.reindex(ridge_coef["Coef."].abs().sort_values(ascending = False).index)
ridge_coef = ridge_coef.reset_index()
plt.figure(figsize = (5,5))
sns.barplot(data = ridge_coef, x = 'Coef.', y = 'index');
plt.title('Coefficients of Ridge Classifier');
plt.ylabel('');

# %%
# joblib.dump(best_ridge,'best_ridge.pkl')

# %% [markdown]
# ## Random Forest

# %%
# randomForest = RandomForestClassifier(random_state = 0, 
#                                       max_features = 'auto', 
#                                       max_depth = 3, 
#                                       class_weight = 'balanced_subsample')
# grid_para_forest = {'n_estimators': range(250,350,10),
#                     'min_samples_split': range(2,9),
#                     'min_samples_leaf' : range(7,12)}

# %%
# grid_search_forest = GridSearchCV(randomForest,
#                                         grid_para_forest,
#                                         cv=skf, 
#                                         n_jobs = 5, 
#                                         verbose = 1,
#                                         return_train_score = True,
#                                         scoring = 'recall')
# # Fit Random Forest 
# para_search = grid_search_forest.fit(X_train, y_train)

# # Save the best estimator
# best_rf = para_search.best_estimator_
# print('Best parameters:', para_search.best_params_)
# Out:
# Fitting 5 folds for each of 350 candidates, totalling 1750 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=5)]: Done 1240 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=5)]: Done 1750 out of 1750 | elapsed:  7.2min finished
# Best parameters: {'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 270}

# %%
rf = RandomForestClassifier(random_state = 0,
                           max_features = 'auto',
                           class_weight = 'balanced_subsample',
                           n_estimators = 860,
                           max_depth = 3,
                           min_samples_split = 3,
                           min_samples_leaf = 3)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', max_depth=3,
#                        min_samples_leaf=3, min_samples_split=3,
#                        n_estimators=860, random_state=0)

# %%
eval_model('Random Forest', rf, X_train, X_test, y_train, y_test)
# Out:
# Random Forest score
# ------------------------------
# Train: recall score: 0.91525
# Test: recall score: 0.91447
#
# Train Test Confusion Matrix
# ------------------------------
# Train Set
# [[2844  589]
#  [  30  324]]
# Test Set
# [[1233  238]
#  [  13  139]]

# %%
sorted_importance = sorted(zip(X_train.columns, rf.feature_importances_), key=lambda t:t[1], reverse=True)
a, b = zip(*sorted_importance)
plt.figure(figsize = (8,15))
df = pd.DataFrame({'feature_name':a, 'importance_score':b})
sns.barplot(data = df, x = 'importance_score', y= 'feature_name', orient = 'h');
plt.title('Feature Importance From Random Forest');
plt.xlabel('Feature Importance Score');
plt.ylabel('Features');

# %%
# joblib.dump(best_rf,'best_rf.pkl')

# %% [markdown]
# ## Gradient Boosting

# %%
sample_weight = compute_sample_weight(class_weight = 'balanced', y = y_train)

# %%
# gb = GradientBoostingClassifier(random_state = 0, max_depth = 2)
# grid_para_gb = {'n_estimators': [300,400,500,1000,2000],
#                 'max_features': [15,17,20,25],
#                 'learning_rate': [0.003, 0.005, 0.01],
#                     'min_samples_split': [17,20,25],
#                     'min_samples_leaf' : [17,20,25]}

# %%
# grid_search_gb = RandomizedSearchCV(gb, 
#                                     grid_para_gb, 
#                                     cv= skf, 
#                                     n_jobs = 5, 
#                                     verbose = 1,
#                                     return_train_score = True,
#                                     scoring = 'recall')
# para_search = grid_search_gb.fit(X_train, y_train, sample_weight = sample_weight)
# best_gb = para_search.best_estimator_
# print('Best parameters:', para_search.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=5)]: Done  50 out of  50 | elapsed:   42.0s finished
# Best parameters: {'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 25, 'learning_rate': 0.005}

# %%
gb = GradientBoostingClassifier(random_state = 0, 
                                max_features = 'auto',
                                n_estimators = 600,
                                learning_rate = 0.003,
                                max_depth = 2,
                                min_samples_leaf = 12,
                                min_samples_split = 12)
gb.fit(X_train,y_train, sample_weight = sample_weight)
# Out:
# GradientBoostingClassifier(learning_rate=0.003, max_depth=2,
#                            max_features='auto', min_samples_leaf=12,
#                            min_samples_split=12, n_estimators=600,
#                            random_state=0)

# %%
eval_model('Gradient Boosting', gb, X_train, X_test, y_train, y_test)
# Out:
# Gradient Boosting score
# ------------------------------
# Train: recall score: 0.91808
# Test: recall score: 0.91447
#
# Train Test Confusion Matrix
# ------------------------------
# Train Set
# [[2922  511]
#  [  29  325]]
# Test Set
# [[1275  196]
#  [  13  139]]

# %%
sorted_importance = sorted(zip(X_train.columns, gb.feature_importances_), key=lambda t:t[1], reverse=True)
a, b = zip(*sorted_importance)
plt.figure(figsize = (8,15))
df = pd.DataFrame({'feature_name':a, 'importance_score':b})
sns.barplot(data = df, x = 'importance_score', y= 'feature_name', orient = 'h');
plt.title('Feature Importance From Gradient Boosting');
plt.xlabel('Feature Importance Score');
plt.ylabel('Features');

# %%
# joblib.dump(best_gb,'best_gb.pkl')

# %% [markdown]
# ## SVM

# %%
# svm = SVC(random_state = 0, class_weight = 'balanced')
# grid_para_svm = {'C':np.logspace(1,5,50),
#                  'gamma': np.logspace(-3,0,50)}

# %%
# grid_search_svm = RandomizedSearchCV(svm, 
#                                     grid_para_svm, 
#                                     cv= skf, 
#                                     n_jobs = 5, 
#                                     verbose = 1,
#                                     return_train_score = True,
#                                     scoring = 'recall')
# para_search = grid_search_svm.fit(X_train_stan, y_train)
# best_svm = para_search.best_estimator_
# print('Best parameters:', para_search.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=5)]: Done  50 out of  50 | elapsed:    8.9s finished
# Best parameters: {'gamma': 0.002329951810515372, 'C': 25.59547922699536}

# %%
svm = SVC(random_state = 0, class_weight = 'balanced',
         C = 12.067926406393289, gamma = 0.010985411419875584)
svm.fit(X_train_stan,y_train)
# Out:
# SVC(C=12.067926406393289, class_weight='balanced', gamma=0.010985411419875584,
#     random_state=0)

# %%
eval_model('SVM', svm, X_train_stan, X_test_stan, y_train, y_test)
# Out:
# SVM score
# ------------------------------
# Train: recall score: 0.92938
# Test: recall score: 0.92763
#
# Train Test Confusion Matrix
# ------------------------------
# Train Set
# [[2787  646]
#  [  25  329]]
# Test Set
# [[1212  259]
#  [  11  141]]

# %%
# joblib.dump(best_svm, 'best_svm.pkl')

# %% [markdown]
# ## GNB

# %%
gnb = GaussianNB()
grid_para_gnb = {'var_smoothing': np.logspace(-4,0,100)}

# %%
grid_search_gnb = GridSearchCV(gnb, 
                                    grid_para_gnb, 
                                    cv= skf, 
                                    n_jobs = 5, 
                                    verbose = 1,
                                    return_train_score = True,
                                    scoring = 'recall')
para_search = grid_search_gnb.fit(X_train_stan, y_train)
best_gnb = para_search.best_estimator_
print('Best parameters:', para_search.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done 150 tasks      | elapsed:    0.7s
# Best parameters: {'var_smoothing': 0.0509413801481638}
# [Parallel(n_jobs=5)]: Done 500 out of 500 | elapsed:    3.4s finished

# %%
eval_model('GNB', best_gnb, X_train_stan, X_test_stan, y_train, y_test)
# Out:
# GNB score
# ------------------------------
# Train: recall score: 0.88136
# Test: recall score: 0.86842
#
# Train Test Confusion Matrix
# ------------------------------
# Train Set
# [[2367 1066]
#  [  42  312]]
# Test Set
# [[1046  425]
#  [  20  132]]

# %%
# joblib.dump(best_gnb, 'best_gnb.pkl')

# %% [markdown]
# # ROC AUC Curve

# %%
print('ROC AUC Scores')
print('-'*30)
print('Logistic Reg.:', roc_auc_score(y_test, best_logistic.predict(X_test_stan)))
print('Ridge Classifier:', roc_auc_score(y_test, best_ridge.predict(X_test_reduced)))
print('Random Forest:', roc_auc_score(y_test, rf.predict(X_test)))
print('Gradient Boosting:', roc_auc_score(y_test, best_gb.predict(X_test)))
print('SVM:', roc_auc_score(y_test, svm.predict(X_test_stan)))
print('GNB:', roc_auc_score(y_test, best_gnb.predict(X_test_stan)))
# Out:
# ROC AUC Scores
# ------------------------------
# Logistic Reg.: 0.8732691688432502
# Ridge Classifier: 0.8694206411678413
# Random Forest: 0.8701004508211383
# Gradient Boosting: 0.8897053561844789
# SVM: 0.8552542130308777
# GNB: 0.7897509749901607

# %%
sns.set_palette('Set1')
random_probs = [0 for i in range(len(y_test))]
fpr, tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
logistic_fpr, logistic_tpr, _ = roc_curve(y_test, best_logistic.predict(X_test_stan))
ridge_fpr, ridge_tpr, _ = roc_curve(y_test, best_ridge.predict(X_test_reduced))
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf.predict(X_test))
gb_fpr, gb_tpr, _ = roc_curve(y_test, best_gb.predict(X_test))
svm_fpr, svm_tpr, _ = roc_curve(y_test, svm.predict(X_test_stan))
gnb_fpr, gnb_tpr, _ = roc_curve(y_test, best_gnb.predict(X_test_stan))


# plot the roc curve for the model
plt.plot(fpr, tpr, linestyle = ':', color = 'gray');
plt.plot(logistic_fpr, logistic_tpr, marker='.', label='Logistic Regression');
plt.plot(ridge_fpr, ridge_tpr, marker='.', label='Ridge Classifier');
plt.plot(rf_fpr, rf_tpr, marker='.', label='Random Forest');
plt.plot(gb_fpr, gb_tpr, marker='.', label='Gradient Boosting');
plt.plot(svm_fpr, svm_tpr, marker='.', label='SVM');
plt.plot(gnb_fpr, gnb_tpr, marker='.', label='GNB');

plt.legend();
plt.title('ROC AUC Curves of Models Used')
plt.xlabel('False Positive Rate');
plt.ylabel('True Positive Rate');
